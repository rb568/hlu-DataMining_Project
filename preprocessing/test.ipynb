# %%
# [Pre-processing 폴더 안내]
# 이 폴더에는 데이터 수집 및 정제를 위한 코드를 업로드해 주세요.

#들어갈 파일 확장자: .ipynb

#작성 규칙
# - 크롤링 코드, API 호출 코드, 결측치 처리 및 데이터 변형 코드가 여기에 들어옵니다.
# - 교수님 지침에 따라 "어떤 데이터를 어떻게 변형했는지" 코드 위에 꼭 주석으로 설명해 주세요.
