# %%
# [Analysis 폴더 안내]
# 이 폴더에는 탐색적 데이터 분석(EDA) 및 시각화 코드를 업로드해 주세요.

#  들어갈 파일 확장자: .ipynb

#  작성 규칙:
# - 데이터의 분포를 확인하거나 관계성을 파악하는 그래프 코드가 여기에 들어옵니다.
# - "시각화를 통해 어떤 인사이트를 얻었는지" 코드 위에 설명을 반드시 추가해 주세요.
