# %%
# [Models 폴더 안내]
# 이 폴더에는 핵심 분석 알고리즘, 예측 모델링, 파인튜닝 코드를 업로드해 주세요.

#  들어갈 파일 확장자: .ipynb

#  작성 규칙:
# - 분류, 관계성, 패턴 발견 등 모델 학습 및 파인튜닝 로직이 여기에 들어옵니다.
# - 모델 고도화를 위해 어떤 구조적/방법론적 고민을 했는지 주석으로 상세히 설명해 주세요.
